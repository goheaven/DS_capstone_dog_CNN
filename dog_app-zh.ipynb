# %% [markdown]
# # 数据科学家纳米学位
#
# ## 卷积神经网络
#
# ## 项目：为小狗识别应用编写算法
#
#
# 这个 Jupyter notebook 向你展示了优达学城最受欢迎的项目，无论在机器学习纳米学位还是人工智能纳米学位都倍受学员青睐。该项目的目标是将狗狗的图片根据品种进行分类。
#
# 如果你想找到一个深度学习和卷积神经网络相关的且有充分指导的毕业项目的话，这就是你的首选。注意，即使你按照这个 notebook 搭建了你的分类器，你仍要写一篇博客文章或部署一个应用来满足毕业项目的要求。
#
# 注意，你其实只需要使用这个 notebook 的一部分（例如，某些代码块或数据），不需要完成整个 notebook，也能满足毕业项目的要求。
#
# ---
#
# 在此 notebook 中，我们已经为你提供一些模板代码，要成功完成此项目，你需要实现其他功能。除此之外，不需要修改所提供的代码。标题中以**（代码实现）**开头的部分表明你必须在下面的代码块中提供其他功能。我们会在每个部分提供说明，并在以 “TODO” 开头的代码块中提供实现细节。请仔细阅读说明。
#
# 除了实现代码之外，还需要回答与项目和代码实现相关的问题。每个小节你需要回答由**'问题 X'** 开头的问题。请仔细阅读每个问题，并在**答案：**下方的文本框中填写答案。我们将根据每个问题的答案以及实现代码评估你提交的项目。
#
# >**注意：**可以通过 **Shift + Enter** 键盘快捷键执行代码和 Markdown 单元格，并且可以通过双击单元格进入编辑模式，编辑 Markdown 单元格。
#
# 审阅标准还包含可选的“锦上添花”建议，可以指导你在满足最低要求的基础上改进项目。如果你决定实现采纳我们的建议，你应该在这个 notebook 中提供你自己的代码。
#
#
#
# ---
# ### 为何要完成这个项目
#
# 在此 notebook 中，你将开发一种可用于移动应用或网络应用的算法。最终你的代码将能够接受任何用户提供的图像作为输入。如果从图像中检测出小狗，该算法将大致识别出小狗品种。如果检测出人脸，该算法将大致识别出最相似的小狗品种。下图显示了最终项目的潜在示例输出（但是我们希望每个学员的算法行为都不一样）。
#
# ![狗狗输出示例](images/sample_dog_output.png)
#
# 在此实际应用中，你需要将一系列模型整合到一起并执行不同的任务，例如，检测图中人脸的算法与推断小狗品种的 CNN 将不一样。有很多地方都可能会出错，并且不存在完美的算法。即使你的答案不完美，也可以创造有趣的用户体验。
#
# ### 项目规划
#
# 我们将此 notebook 分成了几个独立的步骤。你可以通过以下链接浏览此 notebook。
#
# * [第 0 步](#step0)：导入数据集
# * [第 1 步](#step1)：检测人脸
# * [第 2 步](#step2)：检测小狗
# * [第 3 步](#step3)：（从头开始）创建分类小狗品种的 CNN
# * [第 4 步](#step4)：（使用迁移学习）使用分类小狗品种的 CNN
# * [第 5 步](#step5)：（使用迁移学习）创建分类小狗品种的 CNN
# * [第 6 步](#step6)：编写算法
# * [第 7 步](#step7): 测试算法
#
# ---
# <a id='step0'></a>
#
#
# ## 第 0 步：导入数据集
#
# ### 导入狗狗数据集
#
# 在下面的代码单元格中，我们将导入狗狗图片数据集我们在使用 scikit-learn 库的 `load_files` 函数时传进了很多参数：
# - `train_files`, `valid_files`, `test_files` - numpy 数组，包含图片的文件路径
# - `train_targets`, `valid_targets`, `test_targets` - numpy 数组，包含分类标签的独热码
# - `dog_names` - 字符串格式的狗狗品种名称列表，用于标识标签

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('../../../data/dog_images/train')
valid_files, valid_targets = load_dataset('../../../data/dog_images/valid')
test_files, test_targets = load_dataset('../../../data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("../../../data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 导入人类数据集
#
# 在下方的代码单元格中，我们导入人类数据集，文件路径被保存在 numpy 数组      `human_files` 中。

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("../../../data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## 第 1 步：检测人脸
#
# 我们使用 OpenCV 实现的 [Haar 特征级联分类器（Haar feature-based cascade classifiers）](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) 来检测图片中的人脸。OpenCV 提供了很多预训练的人脸检测器，它们以 XML 文件的形式存储在 [github](https://github.com/opencv/opencv/tree/master/data/haarcascades) 上。我们下载了其中一个检测器并存储在 `haarcascades` 目录中。
#
# 在下个代码单元格中，我们将演示如何使用此检测器从样本图像中检测人脸。

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# 在使用任何人脸检测器之前，标准做法是将图像转换为灰度图像。`detectMultiScale` 函数会执行存储在 `face_cascade` 中的分类器并将灰度图像当做参数。
#
# 在上述代码中，`faces` 是一个包含检测到的人脸的 numpy 数组，其中每行对应一张检测到的人脸。检测到的每张人脸都是一个一维数组，其中有四个条目，分别指定了检测到的人脸的边界框。数组中的前两个条目（在上述代码中提取为 `x` 和 `y`）指定了左上角边界框的水平和垂直位置。数组中的后两个条目（提取为 `w` 和 `h`）指定了边界框的宽和高。
#
# ### 编写人脸检测器
#
# 我们可以编写一个函数，如果在图像中检测到人脸，该函数将返回 `True`，否则返回 `False`。此函数称为 `face_detector`，参数为图像的字符串文件路径，并出现在以下代码块中。

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### （代码实现）评估人脸检测器
#
# __问题 1：__ 使用以下代码单元格测试 `face_detector` 函数的性能。
# - 对于 `human_files` 中的前 100 张图像，有多少图像检测到了人脸？
# - 对于 `dog_files` 中的前 100 张图像，有多少图像检测到了人脸？
#
# 理想情况下，我们希望所有人脸图像都能检测到人脸，所有小狗图像都不能检测到人脸。我们的算法不能满足此目标，但是依然达到了可接受的水平。我们针对每个数据集的前 100 张图像提取出文件路径，并将它们存储在 numpy 数组 `human_files_short` 和 `dog_files_short` 中。
#
# __答案：__对于'human_files",人脸检测100%(1.0)。对于‘dog_files'，人脸检测为11%（0.11) - 模型对于小部分狗狗识别为人脸

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
print("Human detected: ",np.mean([face_detector(human_file) for human_file in human_files_short]))
print("Dog detected: ",np.mean([face_detector(dog_file) for dog_file in dog_files_short]))
# Out:
# Human detected:  1.0
# Dog detected:  0.11

# %% [markdown]
# __问题 2：__ 所选的算法使得我们需要告诉用户我们对上传图片有要求，图片中的人脸必须清晰（避免触怒某些急性子用户）。我们期望用户能够配合，你认为这样的期望合理吗？如果你认为不合理，能否想出一种不需要用户上传的图片中必须有清晰人脸的人脸检测方法？
#
# __答案：__不合理，用户图片质量不可控，预期用户配合也无法给出标准。可以考虑采用CNN卷积神经网络算法实现快速识别并给予用户反馈。
#
# 建议在算法中使用 OpenCV 的人脸检测器来检测人脸图像，但是你也可以尝试其他方法，尤其是利用深度学习的方法:)。请在以下代码单元格中设计并测试你自己的人脸检测算法。如果你打算深入 _选做（Optional）_ 任务，记得报告每个数据集上的表现。

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## 第 2 步：检测小狗
#
# 在这一小节，我们使用预训练的 [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) 模型来检测图片中的狗狗。我们的第一行代码下载了 ResNet-50 模型，以及在 [ImageNet](http://www.image-net.org/) 预训练后的权重信息。ImageNet 是一个庞大且常用的数据集，用于图像分类和其他视觉任务。ImageNet 包含 1000 万以上的 URL，每个都链接到包含某个对象的图像，这些对象分成了 [1000 个类别](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a)。输入一个图片，预训练的 ResNet-50 模型预测图片中包含了什么物体，并返回对应的标签（标签是 ImageNet 内置的一些类别）。

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 1s 0us/step

# %% [markdown]
# ### 预处理数据
#
# 当后端使用 TensorFlow 时，Keras CNN 要求输入的是一个 4D 的 numpy 数组（我们也称之为 4 维张量），其形状为：
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# 其中 `nb_samples` 表示图片 (或样本) 的数量， `rows`、 `columns` 和 `channels` 表示每个图片各自的行数、列数和通道数。
#
# `path_to_tensor` 函数接受一个彩色图片的文件路径字符串，返回一个适用于 Keras CNN 训练的四维张量。这个函数首先加载图片，然后将其重新调整为 $224 \times 224$ 像素的形状。接下来，图片被转成 numpy 数组，之后被整理成 4D 张量。在这个案例中，因为我们处理的是彩色图片，每个图片有 3 个通道。还有，我们处理的是单张图片，返回的张量的形状就是：
#
# $$
# (1, 224, 224, 3).
# $$
#
# `paths_to_tensor` 函数接受一个图片路径的字符串 numpy 数组，返回一个四维张量。该张量的形状是：
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# 其中，`nb_samples` 是输入的图片路径中对应的样本数，或者说图片的数目。建议你把 `nb_samples` 认为是 3 维张量的数量（每个 3 维张量就对应数据集里的一张图片） 。

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### 用 ResNet-50 进行预测
#
# 将要输入 ResNet-50 的 4 维向量准备好后，任何 Keras 中其他的预训练过的模型需要一些额外的步骤。首先，RGB 图像的通道要重排，以转换成 BGR。所有预训练的模型都需要再进行归一化，即必须将每张图片的每个像素都减去平均像素值（$[103.939, 116.779, 123.68]$ ，按 RGB 顺序排列，是用 ImageNet 中所有图像的像素值计算得到的）。上述功能在导入的 `preprocess_input` 函数进行代码实现。如果想了解更多，可以参考 `preprocess_input` 的代码[链接](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# 现在我们已经准备好输入 ResNet-50 的数据了，可以开始使用该模型来提取特征了。该功能通过 `predict` 方法实现。该方法会返回一个 numpy 数组。该数组的第 $i$ 项数值表示该模型预测此图片属于第 $i$ 个 ImageNet 分类的概率。这个功能在下面的 `ResNet50_predict_labels` 函数进行代码实现。
#
# 通过对预测概率向量取 argmax，我们得到一个整数，该整数表示该图片所属的类别的序号，我们可以使用这个[字典](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a)找到类别名称。

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### 写一个小狗检测器
#
# 查看该[字典](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a)后，你将发现：小狗对应的类别按顺序排列，对应的键是 151-268（含），包含从 `'Chihuahua'` 到 `'Mexican hairless'` 的所有类别。因此，为了检查某张图片是否由预训练的 ResNet-50 模型检测到狗狗，我们仅仅需要检查上面的`ResNet50_predict_labels` 函数是否返回了介于 151 和 268 之间的一个数（含边界值）。
#
# 我们顺着该思路完成下面的 `dog_detector` 函数，如果检测到图片中有狗狗，它会返回 `True` （如果没有，返回 `False` ）。

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### （代码实现）评估小狗检测器
#
# __问题 3：__ 在以下代码单元格中测试 `dog_detector` 的效果。
# - 对于 `human_files_short` 中的图像，有多少图像检测到了小狗？
# - 对于 `dog_files_short` 中的图像，有多少图像检测到了小狗？
#
# __答案：__
# - 对于 `human_files_short` 中的图像，有100%图像检测到了小狗（0.0）.
# - 对于 `dog_files_short` 中的图像，有100%图像检测到了小狗（1.0）.

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
print(np.mean([dog_detector(human_file) for human_file in human_files_short]))
print(np.mean([dog_detector(dog_file) for dog_file in dog_files_short]))
# Out:
# 0.0
# 1.0

# %% [markdown]
# ---
# <a id='step3'></a>
# ## 第 3 步：（从头开始）创建分类小狗品种的 CNN
#
# 创建好从图像中检测人脸和小狗的函数后，我们需要预测图像中的小狗品种。在这一步，你需要创建一个分类小狗品种的 CNN。你必须从头创建一个 CNN（因此暂时不能使用迁移学习），并且测试准确率必须至少达到 1%。在此 notebook 的第 5 步，你将使用迁移学习创建 CNN，并且能够获得很高的准确率。
#
# 谨慎添加可训练的层！更多的参数意味着更多的训练时长，意味着你更可能需要 GPU 来加速训练过程。幸运的是，Keras 提供了每个周期（epoch）训练时间的简单估计，你可以用这个乘以训练次数得到训练整个模型的时间。
#
# 预测图中小狗的品种是一项非常难的挑战。因为 **即使人类** 要分辨布列塔尼猎犬（Brittany）和威尔斯激飞猎犬（Welsh Springer Spaniel）也很困难。
#
# 布列塔尼猎犬 | 威尔斯激飞猎犬
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# 还有很多其他相似的狗品种（例如卷毛寻回犬 Curly-Coated Retrievers 和美国水猎犬 American Water Spaniels）。
#
# 卷毛寻回犬 | 美国水猎犬
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# 还有，拉布拉多有黄色、巧克力色和黑色品种。基于视觉的算法需要克服这种同一类别差异很大的问题，并决定如何将所有这些不同肤色的小狗分类为相同的品种。
#
# 黄色拉布拉多 | 巧克力色拉布拉多 | 黑色拉布拉多
# - | - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# 随机猜测的效果很差：除了类别数量不太平衡之外，随机猜测的正确概率约为 1/133，准确率不到 1%。
#
# 在深度学习领域，实践比理论知识靠谱得到。请尝试多种不同的架构，并相信你的直觉。希望你可以从学习中获得乐趣！
#
# ### 预处理数据
#
# 我们通过将每个图像中的每个像素除以 255 来重新缩放图像。

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:13<00:00, 90.85it/s]
# 100%|██████████| 835/835 [00:08<00:00, 102.50it/s]
# 100%|██████████| 836/836 [00:08<00:00, 100.76it/s]

# %% [markdown]
# ### （代码实现）模型架构
#
# 创建分类小狗品种的 CNN。在代码单元格的末尾，使用下面的命令来展示模型概述信息：
#
#         model.summary()
#
# 我们已经导入了部分 Python 模块方便你开始，你也可以自由添加你想要添加的模块。如果你卡住了，这里提醒一下，你的模型应该做到在 CPU 上训练相对较快并且训练 5 个周期（epoch）内的准确率 >1%：
#
# ![CNN样例](images/sample_cnn.png)
#
# __问题 4：__ 列出获得最终 CNN 结构的步骤以及每步的推理过程。如果你选择使用上述的结构，描述你为什么认为该 CNN 架构会在这个图像分类任务中表现优秀。
#
# __答案：__按上图提示搭建卷积网络，该网络能取得很好表现的原因： 一方面，卷积层对特征选取并局部感知，这样可以在更高层次对局部做综合操作，最终获取全局信息；此外，池化层对特征降维，减小过拟合，通过MaxPooling保留最强的特征，再通过平均池化，形成一个特征点；最后使用Dense对特征向量进行softmax计算

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

# 第一层卷积层与第一层最大池化层
model.add(Conv2D(filters=16, kernel_size=2, padding='valid', activation='relu',input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=2))

# 第二层卷积层与最大池化层
model.add(Conv2D(filters=32, kernel_size=2, padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

# 第三层卷积层与最大池化层
model.add(Conv2D(filters=64, kernel_size=2, padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

# 添加Global Average Pool
model.add(GlobalAveragePooling2D(data_format='channels_last'))

# 添加Dense
model.add(Dense(133, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 223, 223, 16)      208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 110, 110, 32)      2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 55, 55, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 54, 54, 64)        8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 19,189
# Trainable params: 19,189
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 编译模型

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### （代码实现）训练模型
#
# 在下面的代码单元格中训练你的模型。使用模型检查点来保存验证损失最低的模型信息。
#
# 欢迎你[增加训练数据](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)，但这不是必须的。

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 150

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history = model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6744 - acc: 0.1623Epoch 00001: val_loss improved from inf to 4.05276, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6737 - acc: 0.1620 - val_loss: 4.0528 - val_acc: 0.1018
# Epoch 2/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6577 - acc: 0.1626Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6577 - acc: 0.1627 - val_loss: 4.0980 - val_acc: 0.1162
# Epoch 3/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6609 - acc: 0.1553Epoch 00003: val_loss improved from 4.05276 to 4.03890, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6603 - acc: 0.1555 - val_loss: 4.0389 - val_acc: 0.1174
# Epoch 4/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6515 - acc: 0.1617Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6517 - acc: 0.1620 - val_loss: 4.0692 - val_acc: 0.1114
# Epoch 5/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6438 - acc: 0.1673Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6427 - acc: 0.1672 - val_loss: 4.1659 - val_acc: 0.1066
# Epoch 6/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6453 - acc: 0.1709Epoch 00006: val_loss improved from 4.03890 to 3.99414, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6454 - acc: 0.1710 - val_loss: 3.9941 - val_acc: 0.1305
# Epoch 7/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6294 - acc: 0.1673Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6284 - acc: 0.1674 - val_loss: 4.0888 - val_acc: 0.1210
# Epoch 8/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6286 - acc: 0.1626Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6284 - acc: 0.1626 - val_loss: 4.0263 - val_acc: 0.1210
# Epoch 9/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6239 - acc: 0.1662Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6231 - acc: 0.1663 - val_loss: 4.0507 - val_acc: 0.1246
# Epoch 10/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6215 - acc: 0.1683Epoch 00010: val_loss improved from 3.99414 to 3.99358, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6232 - acc: 0.1681 - val_loss: 3.9936 - val_acc: 0.1222
# Epoch 11/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6136 - acc: 0.1689Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6139 - acc: 0.1692 - val_loss: 4.0087 - val_acc: 0.1234
# Epoch 12/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6074 - acc: 0.1698Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6092 - acc: 0.1698 - val_loss: 4.0118 - val_acc: 0.1150
# Epoch 13/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6091 - acc: 0.1695Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.6092 - acc: 0.1693 - val_loss: 4.0160 - val_acc: 0.1222
# Epoch 14/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5928 - acc: 0.1755Epoch 00014: val_loss improved from 3.99358 to 3.97954, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5934 - acc: 0.1751 - val_loss: 3.9795 - val_acc: 0.1198
# Epoch 15/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5884 - acc: 0.1749Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5885 - acc: 0.1747 - val_loss: 3.9869 - val_acc: 0.1234
# Epoch 16/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5940 - acc: 0.1728Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5930 - acc: 0.1729 - val_loss: 4.0447 - val_acc: 0.1246
# Epoch 17/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5861 - acc: 0.1748Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5857 - acc: 0.1749 - val_loss: 4.0042 - val_acc: 0.1293
# Epoch 18/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5744 - acc: 0.1784Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5751 - acc: 0.1783 - val_loss: 4.0019 - val_acc: 0.1150
# Epoch 19/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5692 - acc: 0.1737Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5700 - acc: 0.1737 - val_loss: 4.0111 - val_acc: 0.1281
# Epoch 20/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5560 - acc: 0.1769Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5557 - acc: 0.1772 - val_loss: 4.0895 - val_acc: 0.1198
# Epoch 21/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5689 - acc: 0.1776Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5674 - acc: 0.1778 - val_loss: 4.0387 - val_acc: 0.1246
# Epoch 22/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5623 - acc: 0.1818Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5613 - acc: 0.1820 - val_loss: 4.0825 - val_acc: 0.1269
# Epoch 23/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5539 - acc: 0.1775Epoch 00023: val_loss improved from 3.97954 to 3.94945, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5540 - acc: 0.1772 - val_loss: 3.9495 - val_acc: 0.1257
# Epoch 24/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5537 - acc: 0.1835Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5540 - acc: 0.1831 - val_loss: 4.0567 - val_acc: 0.1413
# Epoch 25/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5361 - acc: 0.1823Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5372 - acc: 0.1822 - val_loss: 3.9715 - val_acc: 0.1246
# Epoch 26/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5341 - acc: 0.1778Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5340 - acc: 0.1774 - val_loss: 4.0307 - val_acc: 0.1341
# Epoch 27/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5303 - acc: 0.1827Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5300 - acc: 0.1826 - val_loss: 4.1223 - val_acc: 0.1234
# Epoch 28/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5251 - acc: 0.1790Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5259 - acc: 0.1789 - val_loss: 3.9682 - val_acc: 0.1162
# Epoch 29/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5233 - acc: 0.1905Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5226 - acc: 0.1909 - val_loss: 4.0463 - val_acc: 0.1353
# Epoch 30/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5190 - acc: 0.1910Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5199 - acc: 0.1907 - val_loss: 3.9680 - val_acc: 0.1198
# Epoch 31/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5176 - acc: 0.1859Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5177 - acc: 0.1858 - val_loss: 4.1073 - val_acc: 0.1102
# Epoch 32/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5086 - acc: 0.1836Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5087 - acc: 0.1835 - val_loss: 3.9509 - val_acc: 0.1485
# Epoch 33/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5018 - acc: 0.1899Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5022 - acc: 0.1898 - val_loss: 4.0795 - val_acc: 0.1413
# Epoch 34/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5022 - acc: 0.1881Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.5024 - acc: 0.1886 - val_loss: 3.9802 - val_acc: 0.1281
# Epoch 35/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4895 - acc: 0.1871Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4914 - acc: 0.1868 - val_loss: 3.9700 - val_acc: 0.1257
# Epoch 36/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4802 - acc: 0.1892Epoch 00036: val_loss improved from 3.94945 to 3.91178, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4842 - acc: 0.1888 - val_loss: 3.9118 - val_acc: 0.1305
# Epoch 37/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4841 - acc: 0.1898Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4849 - acc: 0.1900 - val_loss: 3.9955 - val_acc: 0.1210
# Epoch 38/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4776 - acc: 0.1937Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4786 - acc: 0.1933 - val_loss: 4.0024 - val_acc: 0.1126
# Epoch 39/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4766 - acc: 0.1947Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4758 - acc: 0.1948 - val_loss: 4.0614 - val_acc: 0.1222
# Epoch 40/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4753 - acc: 0.1914Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4750 - acc: 0.1912 - val_loss: 3.9823 - val_acc: 0.1257
# Epoch 41/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4678 - acc: 0.1953Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4675 - acc: 0.1952 - val_loss: 3.9400 - val_acc: 0.1341
# Epoch 42/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4568 - acc: 0.1976Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4562 - acc: 0.1975 - val_loss: 4.0595 - val_acc: 0.1269
# Epoch 43/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4545 - acc: 0.1922Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4554 - acc: 0.1918 - val_loss: 4.0159 - val_acc: 0.1198
# Epoch 44/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4534 - acc: 0.1998Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4537 - acc: 0.1997 - val_loss: 3.9566 - val_acc: 0.1365
# Epoch 45/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4510 - acc: 0.2014Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4499 - acc: 0.2013 - val_loss: 3.9573 - val_acc: 0.1437
# Epoch 46/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4459 - acc: 0.1971Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4456 - acc: 0.1972 - val_loss: 3.9769 - val_acc: 0.1281
# Epoch 47/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4423 - acc: 0.2014Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4423 - acc: 0.2009 - val_loss: 3.9841 - val_acc: 0.1461
# Epoch 48/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4416 - acc: 0.1995Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4403 - acc: 0.1999 - val_loss: 3.9178 - val_acc: 0.1353
# Epoch 49/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4292 - acc: 0.2000Epoch 00049: val_loss improved from 3.91178 to 3.89195, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4287 - acc: 0.2000 - val_loss: 3.8920 - val_acc: 0.1353
# Epoch 50/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4222 - acc: 0.1991Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4236 - acc: 0.1988 - val_loss: 3.9773 - val_acc: 0.1329
# Epoch 51/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4192 - acc: 0.2033Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4177 - acc: 0.2031 - val_loss: 4.1049 - val_acc: 0.1281
# Epoch 52/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4141 - acc: 0.2020Epoch 00052: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4153 - acc: 0.2018 - val_loss: 3.9639 - val_acc: 0.1413
# Epoch 53/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4084 - acc: 0.2051Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4097 - acc: 0.2048 - val_loss: 3.9520 - val_acc: 0.1305
# Epoch 54/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4118 - acc: 0.2027Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4120 - acc: 0.2027 - val_loss: 4.1053 - val_acc: 0.1401
# Epoch 55/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.4026 - acc: 0.2083Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4023 - acc: 0.2078 - val_loss: 3.9560 - val_acc: 0.1257
# Epoch 56/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3996 - acc: 0.2098Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.4002 - acc: 0.2094 - val_loss: 3.9049 - val_acc: 0.1329
# Epoch 57/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3936 - acc: 0.2107Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3955 - acc: 0.2108 - val_loss: 3.8943 - val_acc: 0.1425
# Epoch 58/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3916 - acc: 0.2102Epoch 00058: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3914 - acc: 0.2102 - val_loss: 4.0554 - val_acc: 0.1329
# Epoch 59/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3934 - acc: 0.2080Epoch 00059: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3948 - acc: 0.2078 - val_loss: 3.9884 - val_acc: 0.1174
# Epoch 60/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3849 - acc: 0.2080Epoch 00060: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3849 - acc: 0.2078 - val_loss: 3.9916 - val_acc: 0.1473
# Epoch 61/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3872 - acc: 0.2144Epoch 00061: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3883 - acc: 0.2142 - val_loss: 3.9282 - val_acc: 0.1341
# Epoch 62/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3748 - acc: 0.2102Epoch 00062: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3769 - acc: 0.2102 - val_loss: 3.9904 - val_acc: 0.1198
# Epoch 63/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3718 - acc: 0.2155Epoch 00063: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3728 - acc: 0.2156 - val_loss: 3.9658 - val_acc: 0.1485
# Epoch 64/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3750 - acc: 0.2141Epoch 00064: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3746 - acc: 0.2141 - val_loss: 3.9840 - val_acc: 0.1413
# Epoch 65/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3650 - acc: 0.2192Epoch 00065: val_loss improved from 3.89195 to 3.88202, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3665 - acc: 0.2187 - val_loss: 3.8820 - val_acc: 0.1329
# Epoch 66/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3663 - acc: 0.2123Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3673 - acc: 0.2118 - val_loss: 3.9086 - val_acc: 0.1365
# Epoch 67/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3602 - acc: 0.2093Epoch 00067: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3612 - acc: 0.2093 - val_loss: 3.9783 - val_acc: 0.1234
# Epoch 68/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3551 - acc: 0.2111Epoch 00068: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3552 - acc: 0.2111 - val_loss: 3.9606 - val_acc: 0.1353
# Epoch 69/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3507 - acc: 0.2165Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3510 - acc: 0.2162 - val_loss: 3.9123 - val_acc: 0.1449
# Epoch 70/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3482 - acc: 0.2129Epoch 00070: val_loss improved from 3.88202 to 3.87605, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3486 - acc: 0.2130 - val_loss: 3.8761 - val_acc: 0.1341
# Epoch 71/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3448 - acc: 0.2162Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3441 - acc: 0.2162 - val_loss: 3.9057 - val_acc: 0.1569
# Epoch 72/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3349 - acc: 0.2210Epoch 00072: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3352 - acc: 0.2210 - val_loss: 3.9198 - val_acc: 0.1485
# Epoch 73/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3384 - acc: 0.2206Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3383 - acc: 0.2205 - val_loss: 3.8984 - val_acc: 0.1317
# Epoch 74/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3326 - acc: 0.2213Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3331 - acc: 0.2208 - val_loss: 3.9342 - val_acc: 0.1521
# Epoch 75/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3263 - acc: 0.2147Epoch 00075: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3275 - acc: 0.2142 - val_loss: 3.8901 - val_acc: 0.1509
# Epoch 76/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3291 - acc: 0.2225Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3277 - acc: 0.2226 - val_loss: 4.0878 - val_acc: 0.1497
# Epoch 77/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3217 - acc: 0.2207Epoch 00077: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3223 - acc: 0.2205 - val_loss: 3.9397 - val_acc: 0.1533
# Epoch 78/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3186 - acc: 0.2240Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3191 - acc: 0.2238 - val_loss: 3.9475 - val_acc: 0.1293
# Epoch 79/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3159 - acc: 0.2260Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3153 - acc: 0.2263 - val_loss: 3.9942 - val_acc: 0.1425
# Epoch 80/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3108 - acc: 0.2230Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3096 - acc: 0.2231 - val_loss: 3.9300 - val_acc: 0.1485
# Epoch 81/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3035 - acc: 0.2236Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3027 - acc: 0.2237 - val_loss: 4.0052 - val_acc: 0.1365
# Epoch 82/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3093 - acc: 0.2234Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3094 - acc: 0.2235 - val_loss: 4.0181 - val_acc: 0.1473
# Epoch 83/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3092 - acc: 0.2218Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.3107 - acc: 0.2217 - val_loss: 3.9046 - val_acc: 0.1341
# Epoch 84/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2973 - acc: 0.2302Epoch 00084: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2972 - acc: 0.2302 - val_loss: 3.8797 - val_acc: 0.1593
# Epoch 85/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.3021 - acc: 0.2215Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2996 - acc: 0.2220 - val_loss: 4.0251 - val_acc: 0.1341
# Epoch 86/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2919 - acc: 0.2257Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2922 - acc: 0.2257 - val_loss: 3.8904 - val_acc: 0.1461
# Epoch 87/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2896 - acc: 0.2279Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2889 - acc: 0.2280 - val_loss: 3.9780 - val_acc: 0.1401
# Epoch 88/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2795 - acc: 0.2311Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2795 - acc: 0.2313 - val_loss: 3.9425 - val_acc: 0.1473
# Epoch 89/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2820 - acc: 0.2309Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2843 - acc: 0.2305 - val_loss: 3.9662 - val_acc: 0.1425
# Epoch 90/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2753 - acc: 0.2336Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2753 - acc: 0.2335 - val_loss: 3.9255 - val_acc: 0.1305
# Epoch 91/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2757 - acc: 0.2267Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2757 - acc: 0.2268 - val_loss: 3.9535 - val_acc: 0.1293
# Epoch 92/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2778 - acc: 0.2329Epoch 00092: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2783 - acc: 0.2326 - val_loss: 4.0230 - val_acc: 0.1377
# Epoch 93/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2673 - acc: 0.2326Epoch 00093: val_loss improved from 3.87605 to 3.87560, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2674 - acc: 0.2325 - val_loss: 3.8756 - val_acc: 0.1401
# Epoch 94/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2687 - acc: 0.2264Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2668 - acc: 0.2269 - val_loss: 3.9437 - val_acc: 0.1653
# Epoch 95/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2621 - acc: 0.2326Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2621 - acc: 0.2325 - val_loss: 3.9298 - val_acc: 0.1485
# Epoch 96/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2683 - acc: 0.2333Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2692 - acc: 0.2337 - val_loss: 3.8863 - val_acc: 0.1222
# Epoch 97/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2689 - acc: 0.2354Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2680 - acc: 0.2355 - val_loss: 3.9557 - val_acc: 0.1713
# Epoch 98/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2558 - acc: 0.2279Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2556 - acc: 0.2283 - val_loss: 3.9150 - val_acc: 0.1485
# Epoch 99/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2571 - acc: 0.2329Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2549 - acc: 0.2331 - val_loss: 3.9168 - val_acc: 0.1473
# Epoch 100/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2519 - acc: 0.2332Epoch 00100: val_loss improved from 3.87560 to 3.84846, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2525 - acc: 0.2331 - val_loss: 3.8485 - val_acc: 0.1593
# Epoch 101/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2406 - acc: 0.2327Epoch 00101: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2397 - acc: 0.2328 - val_loss: 3.9248 - val_acc: 0.1593
# Epoch 102/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2427 - acc: 0.2353Epoch 00102: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2443 - acc: 0.2350 - val_loss: 3.8617 - val_acc: 0.1461
# Epoch 103/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2410 - acc: 0.2369Epoch 00103: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2416 - acc: 0.2370 - val_loss: 3.9893 - val_acc: 0.1509
# Epoch 104/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2282 - acc: 0.2399Epoch 00104: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2281 - acc: 0.2403 - val_loss: 3.9457 - val_acc: 0.1629
# Epoch 105/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2343 - acc: 0.2393Epoch 00105: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2330 - acc: 0.2394 - val_loss: 4.0054 - val_acc: 0.1569
# Epoch 106/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2338 - acc: 0.2407Epoch 00106: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2352 - acc: 0.2403 - val_loss: 3.9087 - val_acc: 0.1353
# Epoch 107/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2274 - acc: 0.2395Epoch 00107: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2289 - acc: 0.2395 - val_loss: 4.0502 - val_acc: 0.1413
# Epoch 108/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2297 - acc: 0.2396Epoch 00108: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2286 - acc: 0.2400 - val_loss: 4.0148 - val_acc: 0.1485
# Epoch 109/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2165 - acc: 0.2345Epoch 00109: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2172 - acc: 0.2341 - val_loss: 3.9030 - val_acc: 0.1569
# Epoch 110/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2264 - acc: 0.2416Epoch 00110: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2247 - acc: 0.2422 - val_loss: 4.1726 - val_acc: 0.1605
# Epoch 111/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2164 - acc: 0.2372Epoch 00111: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2168 - acc: 0.2371 - val_loss: 3.9194 - val_acc: 0.1401
# Epoch 112/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2160 - acc: 0.2435Epoch 00112: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2173 - acc: 0.2431 - val_loss: 3.9315 - val_acc: 0.1473
# Epoch 113/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2096 - acc: 0.2369Epoch 00113: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2092 - acc: 0.2368 - val_loss: 3.8759 - val_acc: 0.1533
# Epoch 114/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2089 - acc: 0.2532Epoch 00114: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2086 - acc: 0.2530 - val_loss: 3.9710 - val_acc: 0.1413
# Epoch 115/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2051 - acc: 0.2494Epoch 00115: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2047 - acc: 0.2493 - val_loss: 4.0191 - val_acc: 0.1317
# Epoch 116/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2002 - acc: 0.2495Epoch 00116: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1994 - acc: 0.2496 - val_loss: 3.9538 - val_acc: 0.1629
# Epoch 117/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2058 - acc: 0.2387Epoch 00117: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2072 - acc: 0.2386 - val_loss: 3.9030 - val_acc: 0.1449
# Epoch 118/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.2035 - acc: 0.2443Epoch 00118: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.2026 - acc: 0.2448 - val_loss: 3.9307 - val_acc: 0.1569
# Epoch 119/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1980 - acc: 0.2459Epoch 00119: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1979 - acc: 0.2461 - val_loss: 3.9834 - val_acc: 0.1509
# Epoch 120/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1935 - acc: 0.2428Epoch 00120: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1928 - acc: 0.2427 - val_loss: 3.8523 - val_acc: 0.1461
# Epoch 121/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1873 - acc: 0.2470Epoch 00121: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1894 - acc: 0.2469 - val_loss: 4.0037 - val_acc: 0.1485
# Epoch 122/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1909 - acc: 0.2426Epoch 00122: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1918 - acc: 0.2428 - val_loss: 3.9502 - val_acc: 0.1437
# Epoch 123/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1807 - acc: 0.2483Epoch 00123: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1815 - acc: 0.2481 - val_loss: 4.0677 - val_acc: 0.1305
# Epoch 124/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1811 - acc: 0.2497Epoch 00124: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1812 - acc: 0.2501 - val_loss: 3.9817 - val_acc: 0.1521
# Epoch 125/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1872 - acc: 0.2428Epoch 00125: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1875 - acc: 0.2425 - val_loss: 3.9402 - val_acc: 0.1497
# Epoch 126/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1801 - acc: 0.2523Epoch 00126: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1812 - acc: 0.2519 - val_loss: 3.8517 - val_acc: 0.1593
# Epoch 127/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1754 - acc: 0.2459Epoch 00127: val_loss improved from 3.84846 to 3.81270, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1766 - acc: 0.2457 - val_loss: 3.8127 - val_acc: 0.1377
# Epoch 128/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1806 - acc: 0.2497Epoch 00128: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1786 - acc: 0.2501 - val_loss: 3.9712 - val_acc: 0.1737
# Epoch 129/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1759 - acc: 0.2514Epoch 00129: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1752 - acc: 0.2512 - val_loss: 3.8983 - val_acc: 0.1389
# Epoch 130/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1700 - acc: 0.2453Epoch 00130: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1694 - acc: 0.2454 - val_loss: 3.9304 - val_acc: 0.1593
# Epoch 131/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1674 - acc: 0.2480Epoch 00131: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1666 - acc: 0.2481 - val_loss: 3.9127 - val_acc: 0.1677
# Epoch 132/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1624 - acc: 0.2559Epoch 00132: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1636 - acc: 0.2555 - val_loss: 3.8418 - val_acc: 0.1545
# Epoch 133/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1716 - acc: 0.2480Epoch 00133: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1708 - acc: 0.2479 - val_loss: 3.9182 - val_acc: 0.1605
# Epoch 134/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1553 - acc: 0.2533Epoch 00134: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1549 - acc: 0.2533 - val_loss: 3.8842 - val_acc: 0.1677
# Epoch 135/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1565 - acc: 0.2550Epoch 00135: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1561 - acc: 0.2551 - val_loss: 4.0877 - val_acc: 0.1413
# Epoch 136/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1543 - acc: 0.2526Epoch 00136: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1540 - acc: 0.2525 - val_loss: 4.1341 - val_acc: 0.1317
# Epoch 137/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1494 - acc: 0.2517Epoch 00137: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1497 - acc: 0.2521 - val_loss: 3.9941 - val_acc: 0.1569
# Epoch 138/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1437 - acc: 0.2572Epoch 00138: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1452 - acc: 0.2569 - val_loss: 3.8309 - val_acc: 0.1497
# Epoch 139/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1378 - acc: 0.2604Epoch 00139: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1404 - acc: 0.2599 - val_loss: 3.8682 - val_acc: 0.1581
# Epoch 140/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1500 - acc: 0.2581Epoch 00140: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1492 - acc: 0.2584 - val_loss: 3.9090 - val_acc: 0.1425
# Epoch 141/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1452 - acc: 0.2562Epoch 00141: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1466 - acc: 0.2563 - val_loss: 3.8349 - val_acc: 0.1593
# Epoch 142/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1432 - acc: 0.2553Epoch 00142: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1417 - acc: 0.2552 - val_loss: 4.0194 - val_acc: 0.1473
# Epoch 143/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1420 - acc: 0.2562Epoch 00143: val_loss improved from 3.81270 to 3.81111, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1431 - acc: 0.2555 - val_loss: 3.8111 - val_acc: 0.1437
# Epoch 144/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1440 - acc: 0.2517Epoch 00144: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1444 - acc: 0.2516 - val_loss: 3.8189 - val_acc: 0.1509
# Epoch 145/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1380 - acc: 0.2613Epoch 00145: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1379 - acc: 0.2609 - val_loss: 3.8312 - val_acc: 0.1593
# Epoch 146/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1374 - acc: 0.2535Epoch 00146: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1377 - acc: 0.2534 - val_loss: 3.9057 - val_acc: 0.1689
# Epoch 147/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1334 - acc: 0.2538Epoch 00147: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1325 - acc: 0.2533 - val_loss: 4.0829 - val_acc: 0.1509
# Epoch 148/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1249 - acc: 0.2613Epoch 00148: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1254 - acc: 0.2609 - val_loss: 3.8142 - val_acc: 0.1665
# Epoch 149/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1158 - acc: 0.2586Epoch 00149: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1178 - acc: 0.2585 - val_loss: 3.8442 - val_acc: 0.1689
# Epoch 150/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1270 - acc: 0.2601Epoch 00150: val_loss did not improve
# 6680/6680 [==============================] - 20s 3ms/step - loss: 3.1274 - acc: 0.2599 - val_loss: 3.8124 - val_acc: 0.1449

# %%
#Display fit result
def display_chart_from_model(fit_result):

    #display accuracy chart
    plt.plot(fit_result.history['acc'])
    plt.plot(fit_result.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuacy')
    plt.xlabel('epoch')
    plt.legend(['train','test'],loc='upper left')
    plt.show()

    #display loss chart
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train','test'],loc='upper left')
    plt.show()

# %%
#display chart of fit results
display_chart_from_model(history)

# %% [markdown]
# ### 加载验证损失最低的模型

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### 训练模型
#
# 在小狗图像测试数据集上尝试模型。确保测试准确率高于 1%。

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 14.5933%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## 第 4 步：使用 CNN 分类小狗品种
#
# 为了在不牺牲准确率的情况下减少训练时间，我们将向你展示如何使用迁移学习的方法训练 CNN。在下面的步骤中，你将亲自动手用迁移学习的方法训练自己的 CNN。
#
# ### 获取瓶颈特征（bottleneck feature）

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### 模型架构
#
# 这个模型使用预训练的 VGG-16 模型作为固定的特征提取器（fixed feature extractor），也就是说，VGG-16 的最后一层卷积层的输出会作为我们模型的输入。我们仅仅加入了一层全局平均池化层（global average pooling layer）和一个全连接层（fully connected layer），后者包含一个节点，该节点和所有狗狗品种的节点相连，并使用 softmax 激活函数。

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 编译模型

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### 训练模型

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

history = VGG16_model.fit(train_VGG16, train_targets, 
                          validation_data=(valid_VGG16, valid_targets),
                          epochs=150, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 12.2428 - acc: 0.1220Epoch 00001: val_loss improved from inf to 10.71025, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 293us/step - loss: 12.2170 - acc: 0.1238 - val_loss: 10.7102 - val_acc: 0.2012
# Epoch 2/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 10.0969 - acc: 0.2777Epoch 00002: val_loss improved from 10.71025 to 9.87228, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 264us/step - loss: 10.0995 - acc: 0.2777 - val_loss: 9.8723 - val_acc: 0.2970
# Epoch 3/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 9.5991 - acc: 0.3407Epoch 00003: val_loss improved from 9.87228 to 9.75535, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 253us/step - loss: 9.6054 - acc: 0.3404 - val_loss: 9.7554 - val_acc: 0.3353
# Epoch 4/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 9.4154 - acc: 0.3699Epoch 00004: val_loss improved from 9.75535 to 9.68180, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 254us/step - loss: 9.4038 - acc: 0.3708 - val_loss: 9.6818 - val_acc: 0.3353
# Epoch 5/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 9.2400 - acc: 0.3924Epoch 00005: val_loss improved from 9.68180 to 9.62379, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 9.2418 - acc: 0.3925 - val_loss: 9.6238 - val_acc: 0.3449
# Epoch 6/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 9.0827 - acc: 0.4082Epoch 00006: val_loss improved from 9.62379 to 9.48121, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 259us/step - loss: 9.0875 - acc: 0.4079 - val_loss: 9.4812 - val_acc: 0.3533
# Epoch 7/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 8.8666 - acc: 0.4264Epoch 00007: val_loss improved from 9.48121 to 9.24228, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 8.8868 - acc: 0.4253 - val_loss: 9.2423 - val_acc: 0.3677
# Epoch 8/150
# 6440/6680 [===========================>..] - ETA: 0s - loss: 8.8347 - acc: 0.4345Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 2s 283us/step - loss: 8.8139 - acc: 0.4352 - val_loss: 9.3192 - val_acc: 0.3737
# Epoch 9/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 8.7917 - acc: 0.4420Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 2s 271us/step - loss: 8.7825 - acc: 0.4425 - val_loss: 9.2643 - val_acc: 0.3760
# Epoch 10/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 8.7513 - acc: 0.4473Epoch 00010: val_loss improved from 9.24228 to 9.22846, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 8.7534 - acc: 0.4466 - val_loss: 9.2285 - val_acc: 0.3808
# Epoch 11/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 8.5958 - acc: 0.4515Epoch 00011: val_loss improved from 9.22846 to 9.03503, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 266us/step - loss: 8.5941 - acc: 0.4516 - val_loss: 9.0350 - val_acc: 0.3964
# Epoch 12/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 8.4200 - acc: 0.4628Epoch 00012: val_loss improved from 9.03503 to 8.89813, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 251us/step - loss: 8.4197 - acc: 0.4629 - val_loss: 8.8981 - val_acc: 0.3892
# Epoch 13/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.2567 - acc: 0.4720Epoch 00013: val_loss improved from 8.89813 to 8.86925, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 261us/step - loss: 8.2580 - acc: 0.4720 - val_loss: 8.8693 - val_acc: 0.3904
# Epoch 14/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 8.1255 - acc: 0.4805Epoch 00014: val_loss improved from 8.86925 to 8.66567, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 8.1281 - acc: 0.4802 - val_loss: 8.6657 - val_acc: 0.4168
# Epoch 15/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 7.9657 - acc: 0.4953Epoch 00015: val_loss improved from 8.66567 to 8.64329, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 269us/step - loss: 7.9638 - acc: 0.4954 - val_loss: 8.6433 - val_acc: 0.4060
# Epoch 16/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.9549 - acc: 0.5006Epoch 00016: val_loss improved from 8.64329 to 8.59426, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 7.9365 - acc: 0.5018 - val_loss: 8.5943 - val_acc: 0.4120
# Epoch 17/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 7.8657 - acc: 0.5022Epoch 00017: val_loss improved from 8.59426 to 8.48744, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 274us/step - loss: 7.8603 - acc: 0.5024 - val_loss: 8.4874 - val_acc: 0.4228
# Epoch 18/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.7572 - acc: 0.5086Epoch 00018: val_loss improved from 8.48744 to 8.43854, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 273us/step - loss: 7.7592 - acc: 0.5084 - val_loss: 8.4385 - val_acc: 0.4240
# Epoch 19/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 7.7168 - acc: 0.5118Epoch 00019: val_loss improved from 8.43854 to 8.36942, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 7.6899 - acc: 0.5126 - val_loss: 8.3694 - val_acc: 0.4287
# Epoch 20/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 7.5370 - acc: 0.5190Epoch 00020: val_loss improved from 8.36942 to 8.14106, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 7.5169 - acc: 0.5204 - val_loss: 8.1411 - val_acc: 0.4431
# Epoch 21/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.4200 - acc: 0.5310Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 7.4062 - acc: 0.5317 - val_loss: 8.1812 - val_acc: 0.4455
# Epoch 22/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.3894 - acc: 0.5361Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 7.3934 - acc: 0.5359 - val_loss: 8.1466 - val_acc: 0.4395
# Epoch 23/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 7.3053 - acc: 0.5393Epoch 00023: val_loss improved from 8.14106 to 8.04528, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 249us/step - loss: 7.3077 - acc: 0.5391 - val_loss: 8.0453 - val_acc: 0.4503
# Epoch 24/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 7.2442 - acc: 0.5445Epoch 00024: val_loss improved from 8.04528 to 7.97813, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 7.2479 - acc: 0.5443 - val_loss: 7.9781 - val_acc: 0.4611
# Epoch 25/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 7.1453 - acc: 0.5494Epoch 00025: val_loss improved from 7.97813 to 7.95376, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 251us/step - loss: 7.1419 - acc: 0.5494 - val_loss: 7.9538 - val_acc: 0.4599
# Epoch 26/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 7.0849 - acc: 0.5567Epoch 00026: val_loss improved from 7.95376 to 7.85261, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 250us/step - loss: 7.1039 - acc: 0.5554 - val_loss: 7.8526 - val_acc: 0.4647
# Epoch 27/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.0855 - acc: 0.5563Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 2s 270us/step - loss: 7.0907 - acc: 0.5558 - val_loss: 7.9453 - val_acc: 0.4587
# Epoch 28/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 7.0796 - acc: 0.5584Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 7.0807 - acc: 0.5582 - val_loss: 7.9507 - val_acc: 0.4503
# Epoch 29/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.0332 - acc: 0.5611Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 2s 262us/step - loss: 7.0678 - acc: 0.5590 - val_loss: 7.9205 - val_acc: 0.4515
# Epoch 30/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 7.0511 - acc: 0.5585Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 2s 289us/step - loss: 7.0427 - acc: 0.5591 - val_loss: 7.9014 - val_acc: 0.4623
# Epoch 31/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 7.0099 - acc: 0.5618Epoch 00031: val_loss improved from 7.85261 to 7.84981, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 250us/step - loss: 7.0101 - acc: 0.5615 - val_loss: 7.8498 - val_acc: 0.4527
# Epoch 32/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.0122 - acc: 0.5617Epoch 00032: val_loss improved from 7.84981 to 7.83640, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 249us/step - loss: 7.0015 - acc: 0.5624 - val_loss: 7.8364 - val_acc: 0.4683
# Epoch 33/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 6.9802 - acc: 0.5654Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 6.9903 - acc: 0.5647 - val_loss: 7.9182 - val_acc: 0.4527
# Epoch 34/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.9920 - acc: 0.5642Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 2s 262us/step - loss: 6.9869 - acc: 0.5645 - val_loss: 7.8917 - val_acc: 0.4611
# Epoch 35/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.9927 - acc: 0.5649Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 2s 289us/step - loss: 6.9772 - acc: 0.5659 - val_loss: 7.8595 - val_acc: 0.4683
# Epoch 36/150
# 6440/6680 [===========================>..] - ETA: 0s - loss: 6.9643 - acc: 0.5660Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 2s 257us/step - loss: 6.9771 - acc: 0.5653 - val_loss: 7.8578 - val_acc: 0.4611
# Epoch 37/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.9719 - acc: 0.5664Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 6.9739 - acc: 0.5663 - val_loss: 7.8506 - val_acc: 0.4671
# Epoch 38/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 6.9494 - acc: 0.5679Epoch 00038: val_loss improved from 7.83640 to 7.82450, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 249us/step - loss: 6.9723 - acc: 0.5665 - val_loss: 7.8245 - val_acc: 0.4683
# Epoch 39/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.9846 - acc: 0.5663Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 2s 254us/step - loss: 6.9718 - acc: 0.5671 - val_loss: 7.9142 - val_acc: 0.4635
# Epoch 40/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.9613 - acc: 0.5677Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 2s 256us/step - loss: 6.9694 - acc: 0.5672 - val_loss: 7.8694 - val_acc: 0.4647
# Epoch 41/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 6.9874 - acc: 0.5661Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 2s 255us/step - loss: 6.9696 - acc: 0.5672 - val_loss: 7.8747 - val_acc: 0.4587
# Epoch 42/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.9628 - acc: 0.5674Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 2s 252us/step - loss: 6.9633 - acc: 0.5672 - val_loss: 7.8547 - val_acc: 0.4611
# Epoch 43/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.9104 - acc: 0.5646Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 2s 270us/step - loss: 6.9090 - acc: 0.5647 - val_loss: 7.9447 - val_acc: 0.4527
# Epoch 44/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 6.8940 - acc: 0.5688Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 6.8642 - acc: 0.5707 - val_loss: 7.9303 - val_acc: 0.4575
# Epoch 45/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 6.8525 - acc: 0.5728Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 2s 259us/step - loss: 6.8537 - acc: 0.5728 - val_loss: 7.8819 - val_acc: 0.4611
# Epoch 46/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 6.8372 - acc: 0.5742Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 2s 272us/step - loss: 6.8512 - acc: 0.5734 - val_loss: 7.8411 - val_acc: 0.4551
# Epoch 47/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.8503 - acc: 0.5734Epoch 00047: val_loss improved from 7.82450 to 7.81296, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 251us/step - loss: 6.8467 - acc: 0.5737 - val_loss: 7.8130 - val_acc: 0.4719
# Epoch 48/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.8330 - acc: 0.5737Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 2s 257us/step - loss: 6.8392 - acc: 0.5734 - val_loss: 7.8801 - val_acc: 0.4671
# Epoch 49/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.8039 - acc: 0.5743Epoch 00049: val_loss improved from 7.81296 to 7.78727, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 251us/step - loss: 6.8097 - acc: 0.5738 - val_loss: 7.7873 - val_acc: 0.4623
# Epoch 50/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 6.7317 - acc: 0.5723Epoch 00050: val_loss improved from 7.78727 to 7.69410, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 248us/step - loss: 6.7022 - acc: 0.5743 - val_loss: 7.6941 - val_acc: 0.4683
# Epoch 51/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 6.5961 - acc: 0.5838Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 2s 261us/step - loss: 6.5920 - acc: 0.5838 - val_loss: 7.7450 - val_acc: 0.4635
# Epoch 52/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 6.5586 - acc: 0.5867Epoch 00052: val_loss improved from 7.69410 to 7.63740, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 257us/step - loss: 6.5428 - acc: 0.5877 - val_loss: 7.6374 - val_acc: 0.4766
# Epoch 53/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 6.4460 - acc: 0.5894Epoch 00053: val_loss improved from 7.63740 to 7.62313, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 259us/step - loss: 6.4497 - acc: 0.5892 - val_loss: 7.6231 - val_acc: 0.4719
# Epoch 54/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 6.3440 - acc: 0.5980Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 2s 265us/step - loss: 6.3518 - acc: 0.5976 - val_loss: 7.6335 - val_acc: 0.4683
# Epoch 55/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 6.3099 - acc: 0.6030Epoch 00055: val_loss improved from 7.62313 to 7.46690, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 261us/step - loss: 6.3075 - acc: 0.6030 - val_loss: 7.4669 - val_acc: 0.4766
# Epoch 56/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.2730 - acc: 0.6064Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 6.2919 - acc: 0.6052 - val_loss: 7.5892 - val_acc: 0.4635
# Epoch 57/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 6.2721 - acc: 0.6038Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 6.2547 - acc: 0.6046 - val_loss: 7.5013 - val_acc: 0.4659
# Epoch 58/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 6.1758 - acc: 0.6126Epoch 00058: val_loss improved from 7.46690 to 7.39236, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 289us/step - loss: 6.1856 - acc: 0.6118 - val_loss: 7.3924 - val_acc: 0.4802
# Epoch 59/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 6.1631 - acc: 0.6140Epoch 00059: val_loss improved from 7.39236 to 7.37438, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 277us/step - loss: 6.1710 - acc: 0.6135 - val_loss: 7.3744 - val_acc: 0.4814
# Epoch 60/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 6.1683 - acc: 0.6153Epoch 00060: val_loss improved from 7.37438 to 7.33062, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 258us/step - loss: 6.1668 - acc: 0.6154 - val_loss: 7.3306 - val_acc: 0.4862
# Epoch 61/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.1524 - acc: 0.6159Epoch 00061: val_loss improved from 7.33062 to 7.32906, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 248us/step - loss: 6.1621 - acc: 0.6154 - val_loss: 7.3291 - val_acc: 0.4838
# Epoch 62/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.1676 - acc: 0.6157Epoch 00062: val_loss improved from 7.32906 to 7.31821, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 254us/step - loss: 6.1605 - acc: 0.6162 - val_loss: 7.3182 - val_acc: 0.4850
# Epoch 63/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.1686 - acc: 0.6158Epoch 00063: val_loss improved from 7.31821 to 7.26999, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 291us/step - loss: 6.1585 - acc: 0.6165 - val_loss: 7.2700 - val_acc: 0.4802
# Epoch 64/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 6.1559 - acc: 0.6169Epoch 00064: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 6.1557 - acc: 0.6169 - val_loss: 7.3771 - val_acc: 0.4814
# Epoch 65/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 6.1504 - acc: 0.6177Epoch 00065: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 6.1569 - acc: 0.6174 - val_loss: 7.2892 - val_acc: 0.4814
# Epoch 66/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.1350 - acc: 0.6176Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 2s 281us/step - loss: 6.1360 - acc: 0.6175 - val_loss: 7.4109 - val_acc: 0.4802
# Epoch 67/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 6.0657 - acc: 0.6191Epoch 00067: val_loss improved from 7.26999 to 7.24217, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 281us/step - loss: 6.0534 - acc: 0.6199 - val_loss: 7.2422 - val_acc: 0.4898
# Epoch 68/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.0633 - acc: 0.6220Epoch 00068: val_loss improved from 7.24217 to 7.20453, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 264us/step - loss: 6.0309 - acc: 0.6240 - val_loss: 7.2045 - val_acc: 0.4970
# Epoch 69/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 6.0272 - acc: 0.6241Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 2s 276us/step - loss: 6.0250 - acc: 0.6243 - val_loss: 7.2244 - val_acc: 0.4946
# Epoch 70/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 6.0228 - acc: 0.6255Epoch 00070: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 6.0205 - acc: 0.6256 - val_loss: 7.2418 - val_acc: 0.4874
# Epoch 71/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 6.0134 - acc: 0.6263Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 2s 266us/step - loss: 6.0179 - acc: 0.6260 - val_loss: 7.2436 - val_acc: 0.4934
# Epoch 72/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 6.0022 - acc: 0.6270Epoch 00072: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 6.0169 - acc: 0.6260 - val_loss: 7.2502 - val_acc: 0.4934
# Epoch 73/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 6.0029 - acc: 0.6269Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 2s 249us/step - loss: 6.0143 - acc: 0.6262 - val_loss: 7.2511 - val_acc: 0.4970
# Epoch 74/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.0199 - acc: 0.6260Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 2s 282us/step - loss: 6.0141 - acc: 0.6263 - val_loss: 7.3009 - val_acc: 0.4862
# Epoch 75/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.0440 - acc: 0.6245Epoch 00075: val_loss improved from 7.20453 to 7.20242, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 262us/step - loss: 6.0138 - acc: 0.6263 - val_loss: 7.2024 - val_acc: 0.4958
# Epoch 76/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.9970 - acc: 0.6276Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 2s 259us/step - loss: 6.0107 - acc: 0.6268 - val_loss: 7.2772 - val_acc: 0.4898
# Epoch 77/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 6.0143 - acc: 0.6265Epoch 00077: val_loss did not improve
# 6680/6680 [==============================] - 2s 277us/step - loss: 6.0121 - acc: 0.6266 - val_loss: 7.2344 - val_acc: 0.4946
# Epoch 78/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 6.0091 - acc: 0.6266Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 6.0106 - acc: 0.6265 - val_loss: 7.2484 - val_acc: 0.5006
# Epoch 79/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 6.0177 - acc: 0.6264Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 2s 251us/step - loss: 6.0097 - acc: 0.6269 - val_loss: 7.2780 - val_acc: 0.4970
# Epoch 80/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.0190 - acc: 0.6261Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 2s 259us/step - loss: 6.0112 - acc: 0.6266 - val_loss: 7.2969 - val_acc: 0.4886
# Epoch 81/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9995 - acc: 0.6274Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 6.0070 - acc: 0.6269 - val_loss: 7.2408 - val_acc: 0.4934
# Epoch 82/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.9808 - acc: 0.6286Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 2s 245us/step - loss: 6.0054 - acc: 0.6271 - val_loss: 7.2576 - val_acc: 0.4850
# Epoch 83/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.9842 - acc: 0.6282Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 2s 251us/step - loss: 6.0015 - acc: 0.6271 - val_loss: 7.3087 - val_acc: 0.4922
# Epoch 84/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9899 - acc: 0.6276Epoch 00084: val_loss did not improve
# 6680/6680 [==============================] - 2s 253us/step - loss: 5.9950 - acc: 0.6272 - val_loss: 7.2966 - val_acc: 0.4874
# Epoch 85/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9866 - acc: 0.6268Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 2s 274us/step - loss: 5.9825 - acc: 0.6269 - val_loss: 7.4093 - val_acc: 0.4826
# Epoch 86/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.9560 - acc: 0.6278Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 5.9647 - acc: 0.6272 - val_loss: 7.3189 - val_acc: 0.4850
# Epoch 87/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.9741 - acc: 0.6267Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 2s 280us/step - loss: 5.9520 - acc: 0.6281 - val_loss: 7.3560 - val_acc: 0.4862
# Epoch 88/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.9165 - acc: 0.6298Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 2s 271us/step - loss: 5.9320 - acc: 0.6289 - val_loss: 7.2630 - val_acc: 0.4934
# Epoch 89/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.9319 - acc: 0.6295Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 2s 284us/step - loss: 5.9289 - acc: 0.6298 - val_loss: 7.2797 - val_acc: 0.4934
# Epoch 90/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.9358 - acc: 0.6295Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 5.9226 - acc: 0.6304 - val_loss: 7.2370 - val_acc: 0.4994
# Epoch 91/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.9007 - acc: 0.6323Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 5.9105 - acc: 0.6317 - val_loss: 7.2749 - val_acc: 0.4958
# Epoch 92/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.9120 - acc: 0.6320Epoch 00092: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 5.9088 - acc: 0.6322 - val_loss: 7.3034 - val_acc: 0.4874
# Epoch 93/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.9016 - acc: 0.6329Epoch 00093: val_loss did not improve
# 6680/6680 [==============================] - 2s 249us/step - loss: 5.9056 - acc: 0.6326 - val_loss: 7.2560 - val_acc: 0.4982
# Epoch 94/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.9094 - acc: 0.6332Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 5.9038 - acc: 0.6335 - val_loss: 7.2625 - val_acc: 0.4934
# Epoch 95/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.8742 - acc: 0.6353Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 2s 271us/step - loss: 5.9038 - acc: 0.6334 - val_loss: 7.2373 - val_acc: 0.4994
# Epoch 96/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.8991 - acc: 0.6335Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 2s 276us/step - loss: 5.9028 - acc: 0.6332 - val_loss: 7.2464 - val_acc: 0.5054
# Epoch 97/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.8958 - acc: 0.6336Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 2s 273us/step - loss: 5.9039 - acc: 0.6331 - val_loss: 7.2616 - val_acc: 0.4982
# Epoch 98/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.9052 - acc: 0.6332Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 5.9029 - acc: 0.6334 - val_loss: 7.2499 - val_acc: 0.4994
# Epoch 99/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.8936 - acc: 0.6342Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 2s 264us/step - loss: 5.9017 - acc: 0.6337 - val_loss: 7.2675 - val_acc: 0.4970
# Epoch 100/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.9032 - acc: 0.6334Epoch 00100: val_loss did not improve
# 6680/6680 [==============================] - 2s 261us/step - loss: 5.9018 - acc: 0.6335 - val_loss: 7.2977 - val_acc: 0.4970
# Epoch 101/150
# 6440/6680 [===========================>..] - ETA: 0s - loss: 5.9143 - acc: 0.6328Epoch 00101: val_loss did not improve
# 6680/6680 [==============================] - 2s 292us/step - loss: 5.9020 - acc: 0.6335 - val_loss: 7.2637 - val_acc: 0.5030
# Epoch 102/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.8991 - acc: 0.6337Epoch 00102: val_loss did not improve
# 6680/6680 [==============================] - 2s 272us/step - loss: 5.9016 - acc: 0.6335 - val_loss: 7.2782 - val_acc: 0.5018
# Epoch 103/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.8673 - acc: 0.6356Epoch 00103: val_loss did not improve
# 6680/6680 [==============================] - 2s 245us/step - loss: 5.9016 - acc: 0.6335 - val_loss: 7.2553 - val_acc: 0.5006
# Epoch 104/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.9207 - acc: 0.6325Epoch 00104: val_loss did not improve
# 6680/6680 [==============================] - 2s 272us/step - loss: 5.9018 - acc: 0.6337 - val_loss: 7.2598 - val_acc: 0.4994
# Epoch 105/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.9100 - acc: 0.6331Epoch 00105: val_loss did not improve
# 6680/6680 [==============================] - 2s 260us/step - loss: 5.9012 - acc: 0.6337 - val_loss: 7.3401 - val_acc: 0.4982
# Epoch 106/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9004 - acc: 0.6339Epoch 00106: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 5.9012 - acc: 0.6338 - val_loss: 7.2841 - val_acc: 0.4970
# Epoch 107/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.8934 - acc: 0.6341Epoch 00107: val_loss did not improve
# 6680/6680 [==============================] - 2s 270us/step - loss: 5.8999 - acc: 0.6337 - val_loss: 7.3100 - val_acc: 0.5006
# Epoch 108/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.8820 - acc: 0.6348Epoch 00108: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 5.9004 - acc: 0.6337 - val_loss: 7.2960 - val_acc: 0.4982
# Epoch 109/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.9019 - acc: 0.6336Epoch 00109: val_loss did not improve
# 6680/6680 [==============================] - 2s 266us/step - loss: 5.9011 - acc: 0.6337 - val_loss: 7.2820 - val_acc: 0.4982
# Epoch 110/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.8987 - acc: 0.6338Epoch 00110: val_loss did not improve
# 6680/6680 [==============================] - 2s 277us/step - loss: 5.9013 - acc: 0.6337 - val_loss: 7.2998 - val_acc: 0.4970
# Epoch 111/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.8875 - acc: 0.6347Epoch 00111: val_loss did not improve
# 6680/6680 [==============================] - 2s 275us/step - loss: 5.9013 - acc: 0.6338 - val_loss: 7.3098 - val_acc: 0.4958
# Epoch 112/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.9034 - acc: 0.6335Epoch 00112: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 5.9010 - acc: 0.6337 - val_loss: 7.2681 - val_acc: 0.4994
# Epoch 113/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.8812 - acc: 0.6349Epoch 00113: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 5.9010 - acc: 0.6337 - val_loss: 7.2973 - val_acc: 0.4994
# Epoch 114/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.9018 - acc: 0.6337Epoch 00114: val_loss did not improve
# 6680/6680 [==============================] - 2s 252us/step - loss: 5.9003 - acc: 0.6338 - val_loss: 7.2853 - val_acc: 0.5030
# Epoch 115/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.8994 - acc: 0.6338Epoch 00115: val_loss did not improve
# 6680/6680 [==============================] - 2s 258us/step - loss: 5.9011 - acc: 0.6337 - val_loss: 7.2821 - val_acc: 0.5030
# Epoch 116/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.8988 - acc: 0.6339Epoch 00116: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 5.9004 - acc: 0.6338 - val_loss: 7.3196 - val_acc: 0.4970
# Epoch 117/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.9059 - acc: 0.6335Epoch 00117: val_loss did not improve
# 6680/6680 [==============================] - 2s 257us/step - loss: 5.9003 - acc: 0.6338 - val_loss: 7.2977 - val_acc: 0.5066
# Epoch 118/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.9108 - acc: 0.6331Epoch 00118: val_loss did not improve
# 6680/6680 [==============================] - 2s 265us/step - loss: 5.9011 - acc: 0.6337 - val_loss: 7.2967 - val_acc: 0.4994
# Epoch 119/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.9021 - acc: 0.6338Epoch 00119: val_loss did not improve
# 6680/6680 [==============================] - 2s 253us/step - loss: 5.9014 - acc: 0.6338 - val_loss: 7.2731 - val_acc: 0.5006
# Epoch 120/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.9148 - acc: 0.6328Epoch 00120: val_loss did not improve
# 6680/6680 [==============================] - 2s 257us/step - loss: 5.8995 - acc: 0.6337 - val_loss: 7.2935 - val_acc: 0.5018
# Epoch 121/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.8934 - acc: 0.6324Epoch 00121: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 5.8805 - acc: 0.6326 - val_loss: 7.3826 - val_acc: 0.4910
# Epoch 122/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.7976 - acc: 0.6358Epoch 00122: val_loss did not improve
# 6680/6680 [==============================] - 2s 268us/step - loss: 5.7991 - acc: 0.6358 - val_loss: 7.3328 - val_acc: 0.5018
# Epoch 123/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.7533 - acc: 0.6405Epoch 00123: val_loss did not improve
# 6680/6680 [==============================] - 2s 277us/step - loss: 5.7570 - acc: 0.6403 - val_loss: 7.2463 - val_acc: 0.4994
# Epoch 124/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 5.7501 - acc: 0.6418Epoch 00124: val_loss did not improve
# 6680/6680 [==============================] - 2s 271us/step - loss: 5.7413 - acc: 0.6424 - val_loss: 7.2194 - val_acc: 0.4994
# Epoch 125/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 5.7350 - acc: 0.6427Epoch 00125: val_loss did not improve
# 6680/6680 [==============================] - 2s 271us/step - loss: 5.7360 - acc: 0.6427 - val_loss: 7.2372 - val_acc: 0.4970
# Epoch 126/150
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.7261 - acc: 0.6440Epoch 00126: val_loss did not improve
# 6680/6680 [==============================] - 2s 269us/step - loss: 5.7307 - acc: 0.6437 - val_loss: 7.2566 - val_acc: 0.5066
# Epoch 127/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.7631 - acc: 0.6416Epoch 00127: val_loss did not improve
# 6680/6680 [==============================] - 2s 308us/step - loss: 5.7288 - acc: 0.6437 - val_loss: 7.2325 - val_acc: 0.4958
# Epoch 128/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 5.7395 - acc: 0.6436Epoch 00128: val_loss did not improve
# 6680/6680 [==============================] - 2s 259us/step - loss: 5.7284 - acc: 0.6443 - val_loss: 7.2390 - val_acc: 0.5066
# Epoch 129/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.7400 - acc: 0.6436Epoch 00129: val_loss did not improve
# 6680/6680 [==============================] - 2s 263us/step - loss: 5.7280 - acc: 0.6443 - val_loss: 7.2054 - val_acc: 0.5030
# Epoch 130/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.7286 - acc: 0.6444Epoch 00130: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 5.7275 - acc: 0.6445 - val_loss: 7.2373 - val_acc: 0.5054
# Epoch 131/150
# 6480/6680 [============================>.] - ETA: 0s - loss: 5.7352 - acc: 0.6438Epoch 00131: val_loss did not improve
# 6680/6680 [==============================] - 2s 264us/step - loss: 5.7276 - acc: 0.6443 - val_loss: 7.2326 - val_acc: 0.5006
# Epoch 132/150
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.7174 - acc: 0.6451Epoch 00132: val_loss did not improve
# 6680/6680 [==============================] - 2s 247us/step - loss: 5.7274 - acc: 0.6445 - val_loss: 7.2168 - val_acc: 0.5066
# Epoch 133/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.7118 - acc: 0.6454Epoch 00133: val_loss did not improve
# 6680/6680 [==============================] - 2s 261us/step - loss: 5.7274 - acc: 0.6445 - val_loss: 7.2361 - val_acc: 0.5006
# Epoch 134/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.7336 - acc: 0.6442Epoch 00134: val_loss did not improve
# 6680/6680 [==============================] - 2s 258us/step - loss: 5.7276 - acc: 0.6446 - val_loss: 7.2484 - val_acc: 0.4994
# Epoch 135/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.7280 - acc: 0.6446Epoch 00135: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 5.7275 - acc: 0.6446 - val_loss: 7.2242 - val_acc: 0.5042
# Epoch 136/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.7148 - acc: 0.6454Epoch 00136: val_loss did not improve
# 6680/6680 [==============================] - 2s 255us/step - loss: 5.7275 - acc: 0.6446 - val_loss: 7.2206 - val_acc: 0.5006
# Epoch 137/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.6875 - acc: 0.6469Epoch 00137: val_loss improved from 7.20242 to 7.18416, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 264us/step - loss: 5.7274 - acc: 0.6445 - val_loss: 7.1842 - val_acc: 0.5006
# Epoch 138/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.7222 - acc: 0.6449Epoch 00138: val_loss improved from 7.18416 to 7.18413, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 5.7275 - acc: 0.6446 - val_loss: 7.1841 - val_acc: 0.5042
# Epoch 139/150
# 6580/6680 [============================>.] - ETA: 0s - loss: 5.7336 - acc: 0.6441Epoch 00139: val_loss did not improve
# 6680/6680 [==============================] - 2s 258us/step - loss: 5.7274 - acc: 0.6445 - val_loss: 7.2196 - val_acc: 0.5078
# Epoch 140/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 5.7341 - acc: 0.6440Epoch 00140: val_loss did not improve
# 6680/6680 [==============================] - 2s 245us/step - loss: 5.7274 - acc: 0.6445 - val_loss: 7.2442 - val_acc: 0.5078
# Epoch 141/150
# 6520/6680 [============================>.] - ETA: 0s - loss: 5.7160 - acc: 0.6448Epoch 00141: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 5.7238 - acc: 0.6443 - val_loss: 7.1858 - val_acc: 0.5030
# Epoch 142/150
# 6620/6680 [============================>.] - ETA: 0s - loss: 5.7097 - acc: 0.6438Epoch 00142: val_loss did not improve
# 6680/6680 [==============================] - 2s 249us/step - loss: 5.7042 - acc: 0.6442 - val_loss: 7.1997 - val_acc: 0.4910
# Epoch 143/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.6983 - acc: 0.6449Epoch 00143: val_loss did not improve
# 6680/6680 [==============================] - 2s 253us/step - loss: 5.6967 - acc: 0.6449 - val_loss: 7.1959 - val_acc: 0.5042
# Epoch 144/150
# 6600/6680 [============================>.] - ETA: 0s - loss: 5.6768 - acc: 0.6459Epoch 00144: val_loss did not improve
# 6680/6680 [==============================] - 2s 252us/step - loss: 5.6812 - acc: 0.6457 - val_loss: 7.2130 - val_acc: 0.5042
# Epoch 145/150
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.6509 - acc: 0.6480Epoch 00145: val_loss improved from 7.18413 to 7.13257, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 248us/step - loss: 5.6590 - acc: 0.6475 - val_loss: 7.1326 - val_acc: 0.5018
# Epoch 146/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.6598 - acc: 0.6474Epoch 00146: val_loss did not improve
# 6680/6680 [==============================] - 2s 269us/step - loss: 5.6475 - acc: 0.6482 - val_loss: 7.1473 - val_acc: 0.5054
# Epoch 147/150
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.6414 - acc: 0.6495Epoch 00147: val_loss improved from 7.13257 to 7.12911, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 268us/step - loss: 5.6438 - acc: 0.6494 - val_loss: 7.1291 - val_acc: 0.4994
# Epoch 148/150
# 6540/6680 [============================>.] - ETA: 0s - loss: 5.6235 - acc: 0.6506Epoch 00148: val_loss did not improve
# 6680/6680 [==============================] - 2s 258us/step - loss: 5.6431 - acc: 0.6494 - val_loss: 7.1386 - val_acc: 0.5030
# Epoch 149/150
# 6440/6680 [===========================>..] - ETA: 0s - loss: 5.6678 - acc: 0.6481Epoch 00149: val_loss did not improve
# 6680/6680 [==============================] - 2s 256us/step - loss: 5.6427 - acc: 0.6497 - val_loss: 7.1530 - val_acc: 0.5006
# Epoch 150/150
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.6376 - acc: 0.6500Epoch 00150: val_loss did not improve
# 6680/6680 [==============================] - 2s 280us/step - loss: 5.6425 - acc: 0.6497 - val_loss: 7.1401 - val_acc: 0.5030

# %%
#Display result of fit
display_chart_from_model(history)

# %% [markdown]
# ### 加载验证损失最低的模型

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### 训练模型
#
# 现在你可以使用 CNN 来测试它在测试集上识别狗狗品种的表现如何了。我们在下面打印出准确率结果。

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 50.5981%

# %% [markdown]
# ### 使用模型预测狗狗的品种

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## 第 5 步：（使用迁移学习）创建分类小狗品种的 CNN
#
# 现在你将使用迁移学习创建能够识别图中小狗品种的 CNN。你的 CNN 必须在测试集上至少达到 60% 的准确率。
#
# 在第 4 步，我们用迁移学习技术从 VGG-16 瓶颈特征创建了一个 CNN 。在这一节，我们要用到不同的预训练的模型的瓶颈特征。为了让任务更简单些，我们预先计算了所有 Keras 实现了的网络的特征：
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) 瓶颈特征
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) 瓶颈特征
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) 瓶颈特征
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) 瓶颈特征
#
# 文件名的格式满足：
#
#     Dog{network}Data.npz
#
# 其中上面 `{network}` 的模型名可以是 `VGG19`、 `Resnet50`  、`InceptionV3` 或 `Xception` 的任意一个。上述的模型架构中选择一个，下载对应的瓶颈特征，然后把下载的文件放入 `bottleneck_features/` 文件夹中。

# %% [markdown]
# ### （代码实现） 获取瓶颈特征（bottleneck feature）
#
# 在下方的代码块中，用如下函数提取训练、测试和验证集的瓶颈特征：

# %% [markdown]
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
#选取Xception模型
bottleneck_features = np.load('/data/bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']

# %% [markdown]
# ### （代码实现）模型架构
#
# 创建分类小狗品种的 CNN。在代码单元格末尾，运行下面这行代码返回模型的概述信息：<your model's name>.summary()

# %% [markdown]
# __问题 5：__列出获得最终 CNN 结构的步骤以及每步的推理过程。解释为何该结构适合解决手头的问题。
#
# __答案：__通过迁移学习，将Xception features的最后一层卷积层作为输入，添加应用平均池化卷积层，最后全联接层使用softmax做输出层。Xception学习快速，通过20 epoc即可获得相对VGG-16更高的准确率。

# %%
### TODO: Define your architecture.
Xception_model = Sequential()

# 第一层卷积层
Xception_model.add(GlobalAveragePooling2D(input_shape=train_Xception.shape[1:]))

# 添加Dense
Xception_model.add(Dense(133, activation='softmax'))

Xception_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### （代码实现） 编译该模型

# %%
### TODO: Compile the model.
Xception_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### （代码实现） 训练模型
#
# 在下面的代码单元格中训练模型。使用模型检查点来保存验证损失最低的模型。
#
# 欢迎你[增加训练数据](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)，但这不是必须的。

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception.hdf5', verbose=1, save_best_only=True)
history = Xception_model.fit(train_Xception, train_targets, 
                             validation_data=(valid_Xception, valid_targets), 
                             epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 1.0677 - acc: 0.7344Epoch 00001: val_loss improved from inf to 0.52730, saving model to saved_models/weights.best.Xception.hdf5
# 6680/6680 [==============================] - 3s 432us/step - loss: 1.0520 - acc: 0.7376 - val_loss: 0.5273 - val_acc: 0.8335
# Epoch 2/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.3928 - acc: 0.8762Epoch 00002: val_loss improved from 0.52730 to 0.48844, saving model to saved_models/weights.best.Xception.hdf5
# 6680/6680 [==============================] - 3s 377us/step - loss: 0.3929 - acc: 0.8765 - val_loss: 0.4884 - val_acc: 0.8443
# Epoch 3/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.3228 - acc: 0.8960Epoch 00003: val_loss improved from 0.48844 to 0.46654, saving model to saved_models/weights.best.Xception.hdf5
# 6680/6680 [==============================] - 3s 389us/step - loss: 0.3213 - acc: 0.8964 - val_loss: 0.4665 - val_acc: 0.8587
# Epoch 4/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.2660 - acc: 0.9171Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 3s 387us/step - loss: 0.2719 - acc: 0.9154 - val_loss: 0.5025 - val_acc: 0.8467
# Epoch 5/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.2448 - acc: 0.9209Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 3s 388us/step - loss: 0.2439 - acc: 0.9216 - val_loss: 0.5218 - val_acc: 0.8611
# Epoch 6/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.2180 - acc: 0.9307Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 3s 375us/step - loss: 0.2174 - acc: 0.9313 - val_loss: 0.5229 - val_acc: 0.8611
# Epoch 7/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1901 - acc: 0.9411Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 2s 374us/step - loss: 0.1894 - acc: 0.9415 - val_loss: 0.5363 - val_acc: 0.8647
# Epoch 8/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.1726 - acc: 0.9471Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 3s 384us/step - loss: 0.1726 - acc: 0.9470 - val_loss: 0.5481 - val_acc: 0.8647
# Epoch 9/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1563 - acc: 0.9483Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 3s 376us/step - loss: 0.1563 - acc: 0.9484 - val_loss: 0.5416 - val_acc: 0.8623
# Epoch 10/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.1491 - acc: 0.9536Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 3s 389us/step - loss: 0.1480 - acc: 0.9540 - val_loss: 0.5791 - val_acc: 0.8515
# Epoch 11/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1318 - acc: 0.9621Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 3s 376us/step - loss: 0.1322 - acc: 0.9621 - val_loss: 0.5590 - val_acc: 0.8587
# Epoch 12/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1234 - acc: 0.9628Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 3s 377us/step - loss: 0.1233 - acc: 0.9627 - val_loss: 0.6011 - val_acc: 0.8599
# Epoch 13/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1122 - acc: 0.9660Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 3s 388us/step - loss: 0.1127 - acc: 0.9657 - val_loss: 0.5860 - val_acc: 0.8539
# Epoch 14/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1050 - acc: 0.9693Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 3s 375us/step - loss: 0.1061 - acc: 0.9689 - val_loss: 0.6330 - val_acc: 0.8575
# Epoch 15/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0931 - acc: 0.9711Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 3s 375us/step - loss: 0.0929 - acc: 0.9711 - val_loss: 0.6094 - val_acc: 0.8563
# Epoch 16/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0893 - acc: 0.9720Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s 374us/step - loss: 0.0886 - acc: 0.9722 - val_loss: 0.6313 - val_acc: 0.8599
# Epoch 17/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0849 - acc: 0.9746Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 3s 378us/step - loss: 0.0845 - acc: 0.9747 - val_loss: 0.6268 - val_acc: 0.8599
# Epoch 18/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0810 - acc: 0.9759Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 3s 376us/step - loss: 0.0796 - acc: 0.9763 - val_loss: 0.6561 - val_acc: 0.8491
# Epoch 19/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0724 - acc: 0.9780Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 3s 376us/step - loss: 0.0734 - acc: 0.9780 - val_loss: 0.6907 - val_acc: 0.8575
# Epoch 20/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0686 - acc: 0.9788Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 3s 387us/step - loss: 0.0692 - acc: 0.9786 - val_loss: 0.6627 - val_acc: 0.8635

# %%
#Display result of fit
display_chart_from_model(history)

# %% [markdown]
# ### （代码实现）加载验证损失最低的模型

# %%
### TODO: Load the model weights with the best validation loss.
Xception_model.load_weights('saved_models/weights.best.Xception.hdf5')

# %% [markdown]
# ### （代码实现）测试模型
#
# 在小狗图像测试数据集上尝试模型。确保测试准确率高于 60%。

# %%
### TODO: Calculate classification accuracy on the test dataset.
Xception_predictions = [np.argmax(Xception_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]
test_accuracy = 100*np.sum(np.array(Xception_predictions)==np.argmax(test_targets, axis=1))/len(Xception_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 84.3301%

# %% [markdown]
# ### （代码实现）使用模型预测小狗品种
#
# 编写一个函数，它会将图像路径作为输入，并返回模型预测的小狗品种（`Affenpinscher`、`Afghan_hound` 等）。
#
# 类似于第 5 步的函数，你的函数应该分 3 步：
# 1. 提取所选择的 CNN 模型的瓶颈特征。
# 2. 将瓶颈特征作为模型的输入返回预测向量。注意预测向量的 argmax 就是预测的狗狗品种的序号。
# 3. 使用 notebook 中第 0 步定义的 `dog_names` 数组来返回对应的狗狗品种。
#
# 用来提取瓶颈特征（即利用网络的卷积层部分，把全连接以上的部分抛掉。然后在我们的训练集和测试集上跑一遍，将得到的输出。即网络在全连接之前的最后一层激活的 feature map）的函数可以在 `extract_bottleneck_features.py` 找到，并且它们已经在前面的单元格中导入了。为了得到你的 CNN 的瓶颈特征，你需要使用函数：extract_{network}

# %% [markdown]
# 其中上面的 `{network}` 模型名应该是 `VGG19`、`Resnet50`、`InceptionV3` 和 `Xception` 其中之一。

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
def Xception_predict_breed(img_path):
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))
    predicted_vector = Xception_model.predict(bottleneck_feature)
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## 第 6 步：编写算法
#
# 编写一个算法，它会将图像的文件路径作为输入，并首先判断图像中是否包含人脸、小狗，或二者都不含。然后，
# - 如果在图像中检测到了__小狗__，则返回预测的品种。
# - 如果在图像中检测到了__人脸__，则返回相似的小狗品种。
# - 如果二者都没检测到，则输出错误消息。
#
# 你可以自己编写从图像中检测人脸和小狗的函数，当然也可以使用上面开发的 `face_detector` 和 `dog_detector` 函数。你**必须**使用在第 5 步创建的 CNN 预测小狗品种。
#
# 下方是函数所需的输入样本图片和输出 ，你也可以自由地设计流程获得更好的用户体验。
#
# ![人脸样本输出](images/sample_human_2.png)
#
# 这张图片看起来像     阿富汗猎犬（Afghan Hound）。
# ### （代码实现）编写算法

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def predict_dog(img_path):
    img = cv2.imread(img_path)
    plt.imshow(img)
    plt.show()
    if dog_detector(img_path):
        print('Dog found. It looks like： ')
        print(Xception_predict_breed(img_path))
        # display the image, along with bounding box
    elif face_detector(img_path):
        print('Human found. It looks like： ')
        print(Xception_predict_breed(img_path))
    else:
        print('ERROR!NOT FOUND!')

# %% [markdown]
# ---
# <a id='step7'></a>
# ## 第 7 步：测试算法
#
# 在此部分中，你可以尽情测试新算法啦！ 算法认为 __这__ 看起来和哪个品种的狗狗比较像？如果你有一只狗，算法能准确预测出小狗的品种吗？如果你有一只猫，算法会错误地认为这只猫是小狗吗？
#
# ### （代码实现）在样本图像上测试算法。
#
# 至少在计算机上用 6 张图像测试你的算法。你可以使用任何图像。至少测试两张人脸图像和两张小狗图像。
#
# __问题 6：__ 结果比你预期的要好吗 :)？ 还是更糟糕 :(？请对你的算法提出至少三个值得改进的地方。
#
# __答案：__ 测试结果符合预期。算法改进的建议，1）尝试一些新的人脸识别算法，比如Haar级联检测；2）对于照片中同时出现多个dog或者human,考虑目标识别算法RCNN等；3）通过增加数据量或者采用交叉验证对实验数据做不同的处理提高模型准确率

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
predict_dog(human_files[100])
predict_dog(human_files[1000])
predict_dog(human_files[5000])


predict_dog(train_files[100])
predict_dog(train_files[1000])
predict_dog(train_files[5000])

predict_dog('images/American_water_spaniel_00648.jpg')
predict_dog('images/Brittany_02625.jpg')
# Out:
# Human found. It looks like：
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# ages/train/119.Petit_basset_griffon_vendeen
# Human found. It looks like：
# ages/train/056.Dachshund
# Human found. It looks like：
# ages/train/012.Australian_shepherd
# Dog found. It looks like：
# ages/train/045.Cardigan_welsh_corgi
# Dog found. It looks like：
# ages/train/048.Chihuahua
# Dog found. It looks like：
# ages/train/103.Mastiff
# Dog found. It looks like：
# ages/train/009.American_water_spaniel
# Dog found. It looks like：
# ages/train/037.Brittany
